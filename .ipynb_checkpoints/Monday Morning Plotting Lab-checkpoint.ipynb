# %%
# %matplotlib inline

# Download the data, save to a file called "housing.data"
import urllib
data_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data"
urllib.urlretrieve (data_url, "housing.data")
# Out:
# ('housing.data', <httplib.HTTPMessage instance at 0x10d7a90e0>)

# %%
names = ["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE",
         "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "MEDV"]

# %%
import pandas as pd
import seaborn as sns

data = pd.read_csv("housing.data", header=None, names=names, delim_whitespace=True)

# Take a look at the first few rows
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# Attribute Information:
#
# 1. CRIM: per capita crime rate by town
# 2. ZN: proportion of residential land zoned for lots over 25,000 sq.ft.
# 3. INDUS: proportion of non-retail business acres per town
# 4. CHAS: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# 5. NOX: nitric oxides concentration (parts per 10 million)
# 6. RM: average number of rooms per dwelling
# 7. AGE: proportion of owner-occupied units built prior to 1940
# 8. DIS: weighted distances to five Boston employment centres
# 9. RAD: index of accessibility to radial highways
# 10. TAX: full-value property-tax rate per $10,000
# 11. PTRATIO: pupil-teacher ratio by town
# 12. B: 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# 13. LSTAT: % lower status of the population
# 14. MEDV: Median value of owner-occupied homes in $1000's

# %%
# Compute the number of rows
data.describe()
#506 rows
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
# Figureing out the data set
data.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %% [markdown]
# Plotting the Data
# We are interested in the house values, given in column "MEDV" as a target for modeling. By plotting each of the other columns against "MEDV" we can get a sense of which variables may be correlated.
# There are many ways we can plot the data, using pandas, matplotlib, or seaborn. In any case, it's nice to import seaborn for the improved styling. Let's try using pandas first to make a scatter plot of crime (column "CRIM") versus house value ("MEDV").

# %%
# Plot using pandas
# MEDV: Median value of owner-occupied homes in $1000's
# CRIM: per capita crime rate by town 

data.plot.scatter(x='CRIM', y='MEDV')
#the lower the median income, the lower the price or MEDV

# %%
# Plot using pandas
# nitric oxides concentration (parts per 10 million) 
# CRIM: per capita crime rate by town 

data.plot.scatter(x='CRIM', y='NOX')

# The higher the rate of NOX, the propensity for crime to increase

# %%
#AGE: proportion of owner-occupied units built prior to 1940
data.plot.scatter(x='AGE', y='MEDV')

# Result= On average, it appears the older the property, the lower the median value. There are some exceptions

# %%
# DIS: weighted distances to five Boston employment centres

data.plot.scatter(x='DIS', y='MEDV')
# Result= On average, it appears the further the distance from center employment district, the HIGHER the median value. There are some exceptions

# %%
#TAX: full-value property-tax rate per $10,000 
# PTRATIO: pupil-teacher ratio by town 
data.plot.scatter(x='TAX', y='PTRATIO')

#Result = i do not see any real coorelation in tax and pupil teacher ratio. Perhaps schools are funded at the state level
#and not the town level?

# %%
# B: 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town 
# CRIM: per capita crime rate by town 

data.plot.scatter(x='B', y='CRIM')
#Result = On average, the proportion of blacks by town is in-elastic and not coorelated

# %%
# MEDV: Median value of owner-occupied homes in $1000's
data.hist(column='MEDV', by=None, grid=False, xlabelsize=None, xrot=None, ylabelsize=None, yrot=None, ax=None, sharex=False, sharey=False, figsize=None, layout=None, bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11f42c190>]], dtype=object)

# %%
#AGE: proportion of owner-occupied units built prior to 1940 
data.hist(column='AGE', by=None, grid=False, xlabelsize=None, xrot=None, ylabelsize=None, yrot=None, ax=None, sharex=False, sharey=False, figsize=None, layout=None, bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11f1c9750>]], dtype=object)

# %%
# I am charting the MEDV of a home, vs the AGE
from matplotlib import pyplot as plt

# Plot using matplotlib
plt.scatter(data["AGE"], data["MEDV"])
plt.xlabel("Age of Home")
plt.ylabel("House Value")

# %%
# Plot using matplotlib
plt.scatter(data["DIS"], data["MEDV"])
plt.xlabel("Distance from Downtown")
plt.ylabel("House Value")

# %%
# Plot using matplotlib
plt.scatter(data["CRIM"], data["NOX"])
plt.xlabel("Crime Per 1000")
plt.ylabel("Nitric Oxide")

# %%
df = data

df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(df, size=5, vars=["CRIM", "AGE"])
